# %% [markdown]
# <a href="https://colab.research.google.com/github/shaye440/DCTNet/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print()
import os
import urllib
import gzip

filepath = 'mnist.pkl.gz'
url = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
if not os.path.isfile(filepath):
  print("Couldn't find MNIST dataset in /tmp, downloading...")
  urllib.request.urlretrieve(url, filepath)
import urllib
import gzip

filepath = '/content/gdrive/My Drive/mnist.pkl.gz'
with gzip.open(filepath, 'rb') as f:
        train_data, dev_data, test_data = pickle.load(f, encoding='bytes')
        print(train_data)
# Out:
# Couldn't find MNIST dataset in /tmp, downloading...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-a8ee8e7533bf> in <module>()
#       8 if not os.path.isfile(filepath):
#       9   print("Couldn't find MNIST dataset in /tmp, downloading...")
# ---> 10   urllib.request.urlretrieve(url, filepath)
#      11 import urllib
#      12 import gzip
#
# AttributeError: module 'urllib' has no attribute 'request'

# %%
import pickle
import pickletools

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip '/content/gdrive/My Drive/resnetForComp2.zip' -d '/content/resC/'
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/resC/resnet/dataset/pic/train/5506.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5507.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5508.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5509.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/551.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5510.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5511.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5512.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5513.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5514.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5515.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5516.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5517.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5518.jpg
#   inflating: /content/resC/resnet/dataset/pic/train/5519.jpg
# ...

# %%
# %run '/content/resC/resnet/main.py'
# Out:
# tensor([[-0.1754, -0.0980,  0.2582,  0.4962,  0.2067, -0.2787]],
#        grad_fn=<AddmmBackward>)
# 0
# 0
# loss: 0.3164832293987274
# loss: 0.32229533791542053
# loss: 0.18155361711978912
# loss: 0.3190377354621887
# loss: 0.18955981731414795
# loss: 0.08527754247188568
# loss: 0.22079110145568848
# loss: 0.35377800464630127
# loss: 0.1939462274312973
# loss: 0.13324852287769318
# accuracy : 0.884375
# weight : torch.Size([6, 2048])
# bias : torch.Size([6])
# 10.1

# %%
torch.save(model.state_dict(), '/content/gdrive/My Drive/modelparaForComp2.pth')

# %%
# !zip -r '/content/gdrive/My Drive/paodaima9FAH.zip' '/content/DCCM-master'
# Out:
#   adding: content/DCCM-master/ (stored 0%)
#   adding: content/DCCM-master/models/ (stored 0%)
#   adding: content/DCCM-master/models/cifar_C4_L2.py (deflated 69%)
#   adding: content/DCCM-master/models/classifier.py (deflated 72%)
#   adding: content/DCCM-master/models/dim_Model.py (deflated 62%)
#   adding: content/DCCM-master/models/__init__.py (deflated 30%)
#   adding: content/DCCM-master/models/__pycache__/ (stored 0%)
#   adding: content/DCCM-master/models/__pycache__/__init__.cpython-36.pyc (deflated 18%)
#   adding: content/DCCM-master/models/__pycache__/dim_Model.cpython-36.pyc (deflated 44%)
#   adding: content/DCCM-master/models/__pycache__/classifier.cpython-36.pyc (deflated 58%)
#   adding: content/DCCM-master/models/__pycache__/cifar_C4_L2.cpython-36.pyc (deflated 43%)
#   adding: content/DCCM-master/.ipynb_checkpoints/ (stored 0%)
#   adding: content/DCCM-master/LICENSE (deflated 66%)
#   adding: content/DCCM-master/fashion/ (stored 0%)
# ...

# %%
# !wget https://codeload.github.com/Cory-M/DCCM/zip/master
# Out:
# --2020-11-01 05:50:16--  https://codeload.github.com/Cory-M/DCCM/zip/master
# Resolving codeload.github.com (codeload.github.com)... 52.68.31.213
# Connecting to codeload.github.com (codeload.github.com)|52.68.31.213|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master’
#
# master                  [  <=>               ] 678.13K  2.75MB/s    in 0.2s
#
# 2020-11-01 05:50:17 (2.75 MB/s) - ‘master’ saved [694404]

# %%
# !unzip '/content/master'
# Out:
# Archive:  /content/master
# 69ed7ae70ba37f07cb85cc116b0ff19a0a637318
#    creating: DCCM-master/
#   inflating: DCCM-master/.gitignore
#   inflating: DCCM-master/LICENSE
#   inflating: DCCM-master/README.md
#   inflating: DCCM-master/_config.yml
#    creating: DCCM-master/cfgs/
#   inflating: DCCM-master/cfgs/cifar10.yaml
#   inflating: DCCM-master/cfgs/cifar100.yaml
#   inflating: DCCM-master/main.py
#    creating: DCCM-master/meta/
#   inflating: DCCM-master/meta/cifar100_meta.txt
#   inflating: DCCM-master/meta/cifar10_meta.txt
#    creating: DCCM-master/models/
#   inflating: DCCM-master/models/__init__.py
#   inflating: DCCM-master/models/cifar_C4_L2.py
#   inflating: DCCM-master/models/classifier.py
#   inflating: DCCM-master/models/dim_Model.py
#    creating: DCCM-master/utils/
#   inflating: DCCM-master/utils/functions.py
#   inflating: DCCM-master/utils/mc_dataset.py
#   inflating: DCCM-master/utils/sampling.py
#   inflating: DCCM-master/utils/util.py

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 9.9MB/s
# ...

# %%
# !unzip '/content/ORL.zip'
# Out:
# Archive:  /content/ORL.zip
#    creating: ORL/
#    creating: ORL/s1/
#   inflating: ORL/s1/1.pgm
#   inflating: ORL/s1/10.pgm
#   inflating: ORL/s1/2.pgm
#   inflating: ORL/s1/3.pgm
#   inflating: ORL/s1/4.pgm
#   inflating: ORL/s1/5.pgm
#   inflating: ORL/s1/6.pgm
#   inflating: ORL/s1/7.pgm
#   inflating: ORL/s1/8.pgm
#   inflating: ORL/s1/9.pgm
#    creating: ORL/s10_female/
#   inflating: ORL/s10_female/1.pgm
#   inflating: ORL/s10_female/10.pgm
#   inflating: ORL/s10_female/2.pgm
#   inflating: ORL/s10_female/3.pgm
#   inflating: ORL/s10_female/4.pgm
#   inflating: ORL/s10_female/5.pgm
#   inflating: ORL/s10_female/6.pgm
#   inflating: ORL/s10_female/7.pgm
#   inflating: ORL/s10_female/8.pgm
#   inflating: ORL/s10_female/9.pgm
#    creating: ORL/s11/
#   inflating: ORL/s11/1.pgm
#   inflating: ORL/s11/10.pgm
#   inflating: ORL/s11/2.pgm
#   inflating: ORL/s11/3.pgm
#   inflating: ORL/s11/4.pgm
#   inflating: ORL/s11/5.pgm
#   inflating: ORL/s11/6.pgm
# ...

# %%
# !pip install tensorboardX
import pickle
import pickleshare
import pickletools
# %run '/content/DCCM-master/main.py' --config /content/DCCM-master/cfgs/cifar10.yaml
# Out:
# ...
# [2020-11-03 01:11:01,730][main.py][line:62][INFO][rank:0] Namespace(arch='cifar_C4_L2', c_layer=19, classifier='SimpleClassifier', config='/content/DCCM-master/cfgs/cifar10.yaml', epochs=20, input_size=32, large_bs=200, layers=[7, 19], lr=0.0001, num_classes=10, print_freq=10, repeated=10, resume=None, root='data/cifar10/', save_path='checkpoint/cifar10', small_bs=32, source='meta/cifar10_meta.txt', split=None, thresh=0.95, workers=16)
# [2020-11-03 01:11:01,730][main.py][line:62][INFO][rank:0] Namespace(arch='cifar_C4_L2', c_layer=19, classifier='SimpleClassifier', config='/content/DCCM-master/cfgs/cifar10.yaml', epochs=20, input_size=32, large_bs=200, layers=[7, 19], lr=0.0001, num_classes=10, print_freq=10, repeated=10, resume=None, root='data/cifar10/', save_path='checkpoint/cifar10', small_bs=32, source='meta/cifar10_meta.txt', split=None, thresh=0.95, workers=16)
# ...

# %%
from utils.mc_dataset import USPDataset

datasetu = USPDataset()
i,c = datasetu.__getitem__(2000)
#print(i)

from matplotlib import pyplot as plt
from PIL import Image
plt.imshow(i)
plt.show()
#print(i)
#print(c)

# %%
$ python main.py --config cfgs/cifar10.yaml
# Out:
#   File "<ipython-input-8-79e28438baf0>", line 1
#     $ python /content/DCCM-master/main.py --config cfgs/cifar10.yaml
#     ^
# SyntaxError: invalid syntax

# %%
# !wget http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Out:
# --2020-11-01 04:13:19--  http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  16.3MB/s    in 12s
#
# 2020-11-01 04:13:31 (14.1 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]

# %%
# !tar -xzvf /content/cifar-10-python.tar.gz
# Out:
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1

# %%
# !unzip '/content/gdrive/My Drive/paodaima8USP.zip' -d '/content/paodaima/'
# Out:
# Archive:  /content/gdrive/My Drive/paodaima8USP.zip
#    creating: /content/paodaima/content/DCCM-master/
#    creating: /content/paodaima/content/DCCM-master/utils/
#   inflating: /content/paodaima/content/DCCM-master/utils/functions.py
#    creating: /content/paodaima/content/DCCM-master/utils/__pycache__/
#   inflating: /content/paodaima/content/DCCM-master/utils/__pycache__/functions.cpython-36.pyc
#   inflating: /content/paodaima/content/DCCM-master/utils/__pycache__/sampling.cpython-36.pyc
#   inflating: /content/paodaima/content/DCCM-master/utils/__pycache__/util.cpython-36.pyc
#   inflating: /content/paodaima/content/DCCM-master/utils/__pycache__/mc_dataset.cpython-36.pyc
#   inflating: /content/paodaima/content/DCCM-master/utils/sampling.py
#   inflating: /content/paodaima/content/DCCM-master/utils/util.py
#   inflating: /content/paodaima/content/DCCM-master/utils/mc_dataset.py
#   inflating: /content/paodaima/content/DCCM-master/main.py
# ...
